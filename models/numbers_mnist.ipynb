# %%
# Importing tensor flow
import tensorflow as tf

# %%
# Loading the dataset
mnist = tf.keras.datasets.mnist

# Dividing the dataset into training and test set
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# Function for normalizing values
def normalize(X):
    return X / 255.0

# %%
# Normalizing values
X_train_norm = normalize(X_train)
X_test_norm = normalize(X_test)

# %%
# Call back to stop training when 99 percent accuracy reached
class MyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs = {}):
        if logs.get('accuracy') > 0.99:
            print("99 percent accuracy reached! Ending training!")
            self.model.stop_training = True

# %%
# Creating the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape = (28, 28)),
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation = 'softmax')
])

# %%
# Compiling the model
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
# Training the model
model.fit(
    X_train_norm,
    y_train,
    epochs = 50,
    callbacks = [MyCallback()]
)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 17s 278us/sample - loss: 0.2991 - accuracy: 0.9133
# Epoch 2/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.1454 - accuracy: 0.9560
# Epoch 3/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1094 - accuracy: 0.9663
# Epoch 4/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0891 - accuracy: 0.9723
# Epoch 5/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0764 - accuracy: 0.9761
# Epoch 6/50
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0669 - accuracy: 0.9791
# Epoch 7/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0588 - accuracy: 0.9811
# Epoch 8/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0530 - accuracy: 0.9829
# Epoch 9/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0500 - accuracy: 0.9829
# Epoch 10/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0451 - accuracy: 0.9848
# Epoch 11/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0436 - accuracy: 0.9851
# Epoch 12/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0394 - accuracy: 0.9867
# Epoch 13/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0370 - accuracy: 0.9873
# Epoch 14/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0363 - accuracy: 0.9880
# Epoch 15/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0343 - accuracy: 0.9884
# Epoch 16/50
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0309 - accuracy: 0.9897
# Epoch 17/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0305 - accuracy: 0.9895
# Epoch 18/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.0292 - accuracy: 0.9900
# Epoch 19/50
# 59616/60000 [============================>.] - ETA: 0s - loss: 0.0279 - accuracy: 0.990399 percent accuracy reached! Ending training!
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0280 - accuracy: 0.9903

# %%
# Evaluate performance on test set
model.evaluate(
    X_test_norm,
    y_test
)
# Out:
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================ ...
# [0.08142642739425719, 0.9794]

# %%
# Save model
model.save('models/my_mnist_model.h5')

# %%
# COnvert model to tensorflow light
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open("models/converted_mnist_model.tflite", "wb").write(tflite_model)
# Out:
# 408324
